# %%
import numpy as np
import gym
import cv2

#init environment
env = gym.make("Breakout-v0")
#grab screen
observation = env.reset()
#view screen
cv2.imshow('Breakout Crop Test',np.array(observation))
#cv2.waitKey(0)

# %%
""" Trains an agent with (stochastic) Policy Gradients on Pong. Uses OpenAI Gym. """
import numpy as np
import pickle
import gym
import cv2

# display features
import matplotlib.pyplot as plt
# %matplotlib inline

# Imports specifically so we can render outputs in Jupyter.
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    #plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    display(display_animation(anim, default_mode='loop'))

# hyperparameters
H = 200 # number of hidden layer neurons
batch_size = 10 # every how many episodes to do a param update?
learning_rate = 1e-4
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
resume = False # resume from previous checkpoint?
render = False # render game to screen after each episode

# model initialization
D = 80 * 80 # input dimensionality: 80x80 grid
if resume:
  model = pickle.load(open('breakout.sav', 'rb'))
else:
  model = {}
  model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
  model['W2'] = np.random.randn(H) / np.sqrt(H)
  
grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

# non-linear activation function
def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

# crop screen and flatten for processing
def prepro(Img):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  Img = Img[35:195] # crop
  gray_image = cv2.cvtColor(Img, cv2.COLOR_BGR2GRAY)
  gray_image = gray_image/142
  gray_image = gray_image[::2,::2] # downsample by factor of 2
#  Img = Img[::2,::2,0] # downsample by factor of 2
#  Img[Img != 0] = 1 # everything else (paddles, ball) just set to 1
  return gray_image.astype(np.float).ravel()

# crop without flatten, for viewing
def prepro2(Img):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  Img = Img[35:195] # crop
  gray_image = cv2.cvtColor(Img, cv2.COLOR_BGR2GRAY)
  gray_image = gray_image/142
  gray_image = gray_image[::2,::2] # downsample by factor of 2
#  Img = Img[::2,::2,0] # downsample by factor of 2
#  Img[Img != 0] = 1 # everything else (paddles, ball) just set to 1
#  print (gray_image)
  return gray_image

#  return I.astype(np.float).ravel()
def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r)
  running_add = 0
  for t in reversed(range(0, r.size)):
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

# feedforward RELU(hidden-layer1), SIGMOID(output)
def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of taking action 2, and hidden state

# calc backpropagation 
def policy_backward(eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

# start environment
env = gym.make("Breakout-v0")
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0
frames = []

# main loop
while True:
  env.step(1)  # fire the ball to start game

  #append frame to list for post episode render
  if resume:
    frames.append(env.render(mode = 'rgb_array'))
    
  #to view crop of screen, comment line above and uncomment line below
  #frames.append(prepro2(observation))
  
  # preprocess the observation, set input to network to be difference image
  cur_x = prepro(observation)

  x = cur_x - prev_x if prev_x is not None else np.zeros(D)
  
  prev_x = cur_x

  # forward the policy network and sample an action from the returned probability
  aprob, h = policy_forward(x)
  action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

  # record various intermediates (needed later for backprop)
  xs.append(x) # observation
  hs.append(h) # hidden state
  y = 1 if action == 2 else 0 # a "fake label"
  dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

  # step the environment and get new measurements
  observation, reward, done, info = env.step(action)
  reward_sum += reward

  drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)
  
   
  if done: # an episode finished
    episode_number += 1

    # stack together all inputs, hidden states, action gradients, and rewards for this episode
    epx = np.vstack(xs)
    eph = np.vstack(hs)
    epdlogp = np.vstack(dlogps)
    epr = np.vstack(drs)
    xs,hs,dlogps,drs = [],[],[],[] # reset array memory

    # compute the discounted reward backwards through time
    discounted_epr = discount_rewards(epr)
    # standardize the rewards to be unit normal (helps control the gradient estimator variance)
    discounted_epr -= np.mean(discounted_epr)
    discounted_epr /= np.std(discounted_epr)

    epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
    grad = policy_backward(eph, epdlogp)
    for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

    # perform rmsprop parameter update every batch_size episodes
    if episode_number % batch_size == 0:
      for k,v in model.items():
        g = grad_buffer[k] # gradient
        rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
        model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
        grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer
    
    #render game
    if render:
      display_frames_as_gif(frames)
        
    # boring book-keeping
    running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
    print ('resetting env. episode reward total was %f. running mean: %f' % (reward_sum, running_reward))
    if episode_number % 100 == 0: pickle.dump(model, open('breakout.sav', 'wb'))
    reward_sum = 0
    observation = env.reset() # reset env
    prev_x = None

  if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
    print ('ep %d: game finished, reward: %f' % (episode_number, reward) + ('' if reward == -1 else ' !!!!!!!!'))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:165: RuntimeWarning: invalid value encountered in true_divide
# resetting env. episode reward total was 0.000000. running mean: 0.000000
# ep 1: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.010000
# resetting env. episode reward total was 0.000000. running mean: 0.009900
# ep 3: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.019801
# resetting env. episode reward total was 0.000000. running mean: 0.019603
# ep 5: game finished, reward: 1.000000 !!!!!!!!
# ep 5: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.039407
# resetting env. episode reward total was 0.000000. running mean: 0.039013
# ep 7: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.048623
# ep 8: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.058137
# resetting env. episode reward total was 0.000000. running mean: 0.057555
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:92: RuntimeWarning: invalid value encountered in less
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:102: RuntimeWarning: invalid value encountered in less_equal
# resetting env. episode reward total was 0.000000. running mean: 0.056980
# ep 11: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.066410
# resetting env. episode reward total was 0.000000. running mean: 0.065746
# ep 13: game finished, reward: 1.000000 !!!!!!!!
# ep 13: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.085088
# ep 14: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.094237
# ep 15: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.103295
# ep 16: game finished, reward: 1.000000 !!!!!!!!
# ep 16: game finished, reward: 1.000000 !!!!!!!!
# ep 16: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was
game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.610603
# resetting env. episode reward total was 0.000000. running mean: 0.604497
# ep 79: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.608452
# ep 80: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.612367
# ep 81: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.616244
# ep 82: game finished, reward: 1.000000 !!!!!!!!
# ep 82: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.630081
# ep 83: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.633780
# ep 84: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.637443
# ep 85: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.641068
# ep 86: game finished, reward: 1.000000 !!!!!!!!
# ep 86: game finished, reward: 1.000000 !!!!!!!!
# ep 86: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 3.000000. running mean: 0.664657
# resetting env. episode reward total was 0.000000. running mean: 0.658011
# ep 88: game finished, reward: 1.000000 !!!!!!!!
# ep 88: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.671431
# ep 89: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.674716
# resetting env. episode reward total was 0.000000. running mean: 0.667969
# ep 91: game finished, reward: 1.000000 !!!!!!!!
# ep 91: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.681290
# resetting env. episode reward total was 0.000000. running mean: 0.674477
# resetting env. episode reward total was 0.000000. running mean: 0.667732
# resetting env. episode reward total was 0.000000. running mean: 0.661055
# resetting env. episode reward total was 0.000000. running mean: 0.654444
# ep 96: game finished, reward: 1.000000 !!!!!!!!
# ep 96: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.667900
# ep 97: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.671221
# ep 98: game finished, reward: 1.000000 !!!!!!!!
# ep 98: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.684508
# ep 99: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.687663
# resetting env. episode reward total was 0.000000. running mean: 0.680787
# ep 101: game finished, reward: 1.000000 !!!!!!!!
# ep 101: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.693979
# resetting env. episode reward total was 0.000000. running mean: 0.687039
# ep 103: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.690169
# ep 104: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.693267
# ep 105: game finished, reward: 1.000000 !!!!!!!!
# ep 105: game finished, reward: 1.000000 !!!!!!!!
# ep 105: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 3.000000. running mean: 0.716334
# ep 106: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.719171
# ep 107: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.721979
# resetting env. episode reward total was 0.000000. running mean: 0.714759
# ep 109: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.717612
# ep 110: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.720436
# ep 111: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.723231
# ep 112: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.725999
# ep 113: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.728739
# ep 114: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.731452
# ep 115: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.734137
# ep 116: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.736796
# ep 117: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.739428
# resetting env. episode reward total was 0.000000. running mean: 0.732034
# ep 119: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.734713
# resetting env. episode reward total was 0.000000. running mean: 0.727366
# resetting env. episode reward total was 0.000000. running mean: 0.720092
# resetting env. episode reward total was 0.000000. running mean: 0.712892
# ep 123: game finished, reward: 1.000000 !!!!!!!!
# ep 123: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.725763
# resetting env. episode reward total was 0.000000. running mean: 0.718505
# ep 125: game finished, reward: 1.000000 !!!!!!!!
# ep 125: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.731320
# ep 126: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.734007
# ep 127: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.736667
# resetting env. episode reward total was 0.000000. running mean: 0.729300
# resetting env. episode reward total was 0.000000. running mean: 0.722007
# resetting env. episode reward total was 0.000000. running mean: 0.714787
# ep 131: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.717639
# ep 132: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.720463
# resetting env. episode reward total was 0.000000. running mean: 0.713258
# resetting env. episode reward total was 0.000000. running mean: 0.706125
# ep 135: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.709064
# ep 136: game finished, reward: 1.000000 !!!!!!!!
# ep 136: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.721974
# resetting env. episode reward total was 0.000000. running mean: 0.714754
# resetting env. episode reward total was 0.000000. running mean: 0.707606
# ep 139: game finished, reward: 1.000000 !!!!!!!!
# ep 139: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 2.000000. running mean: 0.720530
# ep 140: game finished, reward: 1.000000 !!!!!!!!
# resetting env. episode reward total was 1.000000. running mean: 0.723325
# resetting env. episode reward total was 0.000000. running mean: 0.716092
# resetting env. episode reward total was 0.000000. running mean: 0.708931
# ep 143: game finished, reward: 1.000000 !!!!!!!!
